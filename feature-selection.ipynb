# %% [markdown]
# # WiDS 2018 Datathon

# %% [markdown]
# Predictive Analytics for Social Impact
#
# Competition on [Kaggle](https://www.kaggle.com/c/wids2018datathon)

# %% [markdown]
# ## 0. Import Libraries

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier
from helpers import format_submission

# %% [markdown]
# ## 1. Load and Prepare Data

# %%
seed = 37

print 'Loading data...\n'
train = pd.read_csv('data/train.csv', low_memory=False)
test = pd.read_csv('data/test.csv', low_memory=False)

print 'Train Shape: {}'.format(train.shape)
print 'Test Shape: {}\n'.format(test.shape)

label = train['is_female']
del train['is_female']

del train['train_id']
del test['test_id']

# Remove rows/columns that are missing all data
train = train.dropna(axis=0, how='all')
train = train.dropna(axis=1, how='all')

# Convert to dummy variables
print 'Converting to dummy variables...\n'
train_str = train.applymap(str)
train_dummies = pd.get_dummies(train_str)

# Split into train and validation set
print 'Splitting into train and validation set...\n'
X_train, X_test, y_train, y_test = train_test_split(train_dummies, label, test_size=0.2, random_state=seed)

print 'Complete.'
# Out:
# Loading data...
#
# Train Shape: (18255, 1235)
# Test Shape: (27285, 1234)
#
# Converting to dummy variables...
#
# Splitting into train and validation set...
#
# Complete.

# %% [markdown]
# ## 2. Feature Selection

# %%
def log_reg(trainX, trainY, testX, testY):
    print 'Fitting logistic regression...\n'
    clf = LogisticRegression(C=0.2, penalty='l1', solver='liblinear')
    clf.fit(trainX, trainY)
    preds = clf.predict(testX)
    score = roc_auc_score(testY, preds)
    return score

def xgb_clf(trainX, trainY, testX, testY, seed):
    print 'Fitting XGB Classifier...\n'
    clf = XGBClassifier(max_depth=7, n_estimators=100, random_state=seed)
    clf.fit(trainX, trainY, eval_metric='auc')
    preds = clf.predict(testX)
    score = roc_auc_score(testY, preds)
    return score

# %%
# Variance Threshold 
print 'Selecting features with VarianceThreshold...\n'
for t in np.arange(0.0, 0.16, 0.01):
    sel = VarianceThreshold(threshold=t)
    X_train_new = sel.fit_transform(X_train)
    X_test_new = sel.transform(X_test)

    start = time.time()
    score = log_reg(X_train_new, y_train, X_test_new, y_test)
    end = time.time()
    run_time = float(end - start)/60

    print 'Logistic Regression with VarianceThreshold of {}'.format(t)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)

    start = time.time()
    score = xgb_clf(X_train_new, y_train, X_test_new, y_test, seed)
    end = time.time()
    run_time = float(end - start)/60

    print 'XGBoost Classifier with VarianceThreshold of {}'.format(t)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)


# SelectKBest 
print 'Selecting features with SelectKBest...\n'
for k in range(995,1006,1):
    ch2 = SelectKBest(chi2, k=k)
    X_train_new = ch2.fit_transform(X_train, y_train)
    X_test_new = ch2.transform(X_test)

    start = time.time()
    score = log_reg(X_train_new, y_train, X_test_new, y_test)
    end = time.time()
    run_time = float(end - start)/60

    print 'Logistic Regression with SelectKBest, {} Features'.format(k)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)

    start = time.time()
    score = xgb_clf(X_train_new, y_train, X_test_new, y_test, seed)
    end = time.time()
    run_time = float(end - start)/60

    print 'XGBoost Classifier with SelectKBest, {} Features'.format(k)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)


# SelectFromModel
print 'Selecting features with SelectFromModel...\n'
clf = XGBClassifier(max_depth=7, n_estimators=100, random_state=seed)
sfm = SelectFromModel(clf, threshold='median')
X_train_new = sfm.fit_transform(X_train, y_train)
X_test_new = sfm.transform(X_test)

start = time.time()
score = log_reg(X_train_new, y_train, X_test_new, y_test)
end = time.time()
run_time = float(end - start)/60

print 'Logistic Regression with SelectFromModel (Threshold = Median)'
print 'ROC AUC Score: {}'.format(score)
print 'Run time: {:0.2f} minutes\n'.format(run_time)

start = time.time()
score = xgb_clf(X_train_new, y_train, X_test_new, y_test, seed)
end = time.time()
run_time = float(end - start)/60

print 'XGBoost Classifier with SelectFromModel (Threshold = Median)'
print 'ROC AUC Score: {}'.format(score)
print 'Run time: {:0.2f} minutes\n'.format(run_time)


# PCA
print 'Selecting features with PCA...\n'
n='mle'
solver='full'
for w in [True, False]:
    pca = PCA(n_components=n, whiten=w, svd_solver=solver, random_state=seed)
    pca_train = pca.fit_transform(X_train)
    pca_test = pca.transform(X_test)

    start = time.time()
    score = log_reg(pca_train, y_train, pca_test, y_test)
    end = time.time()
    run_time = float(end - start)/60

    print 'Logistic Regression with PCA, {} Components, Whitened = {}'.format(pca.n_components_, w)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)

    start = time.time()
    score = xgb_clf(pca_train, y_train, pca_test, y_test, seed)
    end = time.time()
    run_time = float(end - start)/60

    print 'XGBoost Classifier with PCA, {} Components, Whitened = {}'.format(pca.n_components_, w)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)
# Out:
# Selecting features with VarianceThreshold...
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.0
# ROC AUC Score: 0.902420528395
# Run time: 0.05 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.0
# ROC AUC Score: 0.905588094399
# Run time: 15.59 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.01
# ROC AUC Score: 0.900150944078
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.01
# ROC AUC Score: 0.905400092193
# Run time: 3.66 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.02
# ROC AUC Score: 0.899809738153
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.02
# ROC AUC Score: 0.904112096315
# Run time: 2.83 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.03
# ROC AUC Score: 0.900874933341
# Run time: 0.05 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.03
# ROC AUC Score: 0.903151296583
# Run time: 2.38 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.04
# ROC AUC Score: 0.9007357394
# Run time: 0.04 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.04
# ROC AUC Score: 0.904592496181
# Run time: 2.17 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.05
# ROC AUC Score: 0.899447743522
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.05
# ROC AUC Score: 0.904933702107
# Run time: 1.90 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.06
# ROC AUC Score: 0.89721295769
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.06
# ROC AUC Score: 0.906326093441
# Run time: 1.82 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.07
# ROC AUC Score: 0.893815360142
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.07
# ROC AUC Score: 0.902016504424
# Run time: 1.63 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.08
# ROC AUC Score: 0.891462169075
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.08
# ROC AUC Score: 0.903339298788
# Run time: 1.51 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.09
# ROC AUC Score: 0.893780561657
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.09
# ROC AUC Score: 0.901689308278
# Run time: 1.42 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.1
# ROC AUC Score: 0.893369758761
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.1
# ROC AUC Score: 0.898201325054
# Run time: 1.38 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.11
# ROC AUC Score: 0.891065375959
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.11
# ROC AUC Score: 0.901689308278
# Run time: 1.33 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.12
# ROC AUC Score: 0.890654573063
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.12
# ROC AUC Score: 0.899113316522
# Run time: 1.25 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.13
# ROC AUC Score: 0.889777380081
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.13
# ROC AUC Score: 0.899162124786
# Run time: 1.14 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.14
# ROC AUC Score: 0.886714209532
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.14
# ROC AUC Score: 0.897992534143
# Run time: 1.09 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with VarianceThreshold of 0.15
# ROC AUC Score: 0.886025018755
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with VarianceThreshold of 0.15
# ROC AUC Score: 0.898236123539
# Run time: 1.00 minutes
#
# Selecting features with SelectKBest...
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 995 Features
# ROC AUC Score: 0.898967343655
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 995 Features
# ROC AUC Score: 0.907460885599
# Run time: 1.80 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 996 Features
# ROC AUC Score: 0.89893254517
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 996 Features
# ROC AUC Score: 0.907460885599
# Run time: 1.81 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 997 Features
# ROC AUC Score: 0.898382548334
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 997 Features
# ROC AUC Score: 0.907460885599
# Run time: 1.79 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 998 Features
# ROC AUC Score: 0.898090150673
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 998 Features
# ROC AUC Score: 0.906242486691
# Run time: 1.83 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 999 Features
# ROC AUC Score: 0.898382548334
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 999 Features
# ROC AUC Score: 0.906242486691
# Run time: 1.82 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1000 Features
# ROC AUC Score: 0.898897746685
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1000 Features
# ROC AUC Score: 0.906242486691
# Run time: 1.80 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1001 Features
# ROC AUC Score: 0.89893254517
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1001 Features
# ROC AUC Score: 0.906242486691
# Run time: 1.79 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1002 Features
# ROC AUC Score: 0.898382548334
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1002 Features
# ROC AUC Score: 0.90588049206
# Run time: 1.81 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1003 Features
# ROC AUC Score: 0.898347749849
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1003 Features
# ROC AUC Score: 0.90804568092
# Run time: 1.80 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1004 Features
# ROC AUC Score: 0.898897746685
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1004 Features
# ROC AUC Score: 0.90595008903
# Run time: 1.83 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with SelectKBest, 1005 Features
# ROC AUC Score: 0.898382548334
# Run time: 0.01 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectKBest, 1005 Features
# ROC AUC Score: 0.907342480364
# Run time: 1.87 minutes
#
# Selecting features with SelectFromModel...
#
# Fitting logistic regression...
#
# Logistic Regression with SelectFromModel (Threshold = Median)
# ROC AUC Score: 0.901097734031
# Run time: 0.06 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with SelectFromModel (Threshold = Median)s
# ROC AUC Score: 0.905588094399
# Run time: 16.30 minutes
#
# Selecting features with PCA...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a103407139fe> in <module>()
#      83 for w in [True, False]:
#      84     pca = PCA(n_components=n, whiten=w, svd_solver=solver, random_state=seed)
# ---> 85     pca_train = pca.fit_transform(X_train)
#      86     pca_test = pca.transform(X_test)
#      87
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in fit_transform(self, X, y)
#     322
#     323         """
# --> 324         U, S, V = self._fit(X)
#     325         U = U[:, :self.n_components_]
#     326
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _fit(self, X)
#     366         # Call different fits for either full or truncated SVD
#     367         if svd_solver == 'full':
# --> 368             return self._fit_full(X, n_components)
#     369         elif svd_solver in ['arpack', 'randomized']:
#     370             return self._fit_truncated(X, n_components, svd_solver)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _fit_full(self, X, n_components)
#     401         if n_components == 'mle':
#     402             n_components = \
# --> 403                 _infer_dimension_(explained_variance_, n_samples, n_features)
#     404         elif 0 < n_components < 1.0:
#     405             # number of components for which the cumulated explained
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _infer_dimension_(spectrum, n_samples, n_features)
#     100     ll = np.empty(n_spectrum)
#     101     for rank in range(n_spectrum):
# --> 102         ll[rank] = _assess_dimension_(spectrum, rank, n_samples, n_features)
#     103     return ll.argmax()
#     104
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _assess_dimension_(spectrum, rank, n_samples, n_features)
#      85         for j in range(i + 1, len(spectrum)):
#      86             pa += log((spectrum[i] - spectrum[j]) *
# ---> 87                       (1. / spectrum_[j] - 1. / spectrum_[i])) + log(n_samples)
#      88
#      89     ll = pu + pl + pv + pp - pa / 2. - rank * log(n_samples) / 2.
#
# KeyboardInterrupt:

# %%
# PCA
print 'Selecting features with PCA...\n'
#n='mle'
#solver='full'
n=610
solver='auto'
for w in [True, False]:
    pca = PCA(n_components=n, whiten=w, svd_solver=solver, random_state=seed)
    pca_train = pca.fit_transform(X_train)
    pca_test = pca.transform(X_test)

    start = time.time()
    score = log_reg(pca_train, y_train, pca_test, y_test)
    end = time.time()
    run_time = float(end - start)/60

    print 'Logistic Regression with PCA, {} Components, Whitened = {}'.format(n, w)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)

    start = time.time()
    score = xgb_clf(pca_train, y_train, pca_test, y_test, seed)
    end = time.time()
    run_time = float(end - start)/60

    print 'XGBoost Classifier with PCA, {} Components, Whitened = {}'.format(n, w)
    print 'ROC AUC Score: {}'.format(score)
    print 'Run time: {:0.2f} minutes\n'.format(run_time)
# Out:
# Selecting features with PCA...
#
# Fitting logistic regression...
#
# Logistic Regression with PCA, 610 Components, Whitened = True
# ROC AUC Score: 0.896767356309
# Run time: 0.03 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with PCA, 610 Components, Whitened = True
# ROC AUC Score: 0.858323616873
# Run time: 2.61 minutes
#
# Fitting logistic regression...
#
# Logistic Regression with PCA, 610 Components, Whitened = False
# ROC AUC Score: 0.894226163038
# Run time: 0.02 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with PCA, 610 Components, Whitened = False
# ROC AUC Score: 0.858323616873
# Run time: 2.57 minutes

# %%
# All features
start = time.time()
score = log_reg(X_train, y_train, X_test, y_test)
end = time.time()
run_time = float(end - start)/60

print 'Logistic Regression with All Features'
print 'ROC AUC Score: {}'.format(score)
print 'Run time: {:0.2f} minutes\n'.format(run_time)

start = time.time()
score = xgb_clf(X_train, y_train, X_test, y_test, seed)
end = time.time()
run_time = float(end - start)/60

print 'XGBoost Classifier with All Features'
print 'ROC AUC Score: {}'.format(score)
print 'Run time: {:0.2f} minutes\n'.format(run_time)
# Out:
# Fitting logistic regression...
#
# Logistic Regression with All Features
# ROC AUC Score: 0.902162929219
# Run time: 0.09 minutes
#
# Fitting XGB Classifier...
#
# XGBoost Classifier with All Features
# ROC AUC Score: 0.905588094399
# Run time: 16.14 minutes
